# %% [markdown]
# <a href="https://colab.research.google.com/github/konverner/subtitles-generator/blob/main/notebooks/subtitles_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install
#
# This only installs `transformers`/`accelerate` on top of what Colab already ships (torch, ffmpeg). It intentionally does **not** touch your existing torch install.

# %%
# !git clone https://github.com/konverner/subtitles-generator.git
# %cd /content/subtitles-generator
# !pip install -q .

# %% [markdown]
# Run with the `large` model, auto-detecting the language, on `videos/test.mp4`.
#
# Subtitles will be saved as `videos/test.srt`.

# %%
# !python main.py --model_size large --lang auto --input_file videos/test.mp4
